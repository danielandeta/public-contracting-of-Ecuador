# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("../data/dataset-RedFlags.csv")
df
# Out:
#        Unnamed: 0                                     ocid  \
# 0               0    ocds-5wno2w-REGES-MPORTO-2021-13-2332
# 1               1       ocds-5wno2w-RE-EEASA-142-2021-3233
# 2               2    ocds-5wno2w-LICS-UNEMI-013-2021-43664
# 3               3  ocds-5wno2w-RE-EP-GMJ-DGF-1-2021-102953
# 4               4     ocds-5wno2w-LIC-EPFLP-01-2021-404551
# ...           ...                                      ...
# 84696       84696   ocds-5wno2w-RE-EPMAPAS-001-2021-279324
# 84697       84697     ocds-5wno2w-RE-SC-MDMQ-08-2021-41357
# 84698       84698    ocds-5wno2w-REOALC-GADMANTA01-21-2668
# 84699       84699    ocds-5wno2w-RE-GADMCN-17-21-LRG-67188
# 84700       84700     ocds-5wno2w-RE-HGADPCH-039-2021-2583
#
#                                                       id initiationType  \
# 0      REGES-MPORTO-2021-13-2332-2022-05-07T11:56:24....         tender
# 1      RE-EEASA-142-2021-3233-2022-05-10T11:35:00.178...         tender
# 2      LICS-UNEMI-013-2021-43664-2022-05-11T11:32:30....         tender
# 3      RE-EP-GMJ-DGF-1-2021-102953-2022-05-11T11:34:5...         tender
# 4      LIC-EPFLP-01-2021-404551-2022-05-14T12:25:47.8...         tender
# ...                                                  ...            ...
# 84696  RE-EPMAPAS-001-2021-279324-2022-04-28T11:33:29...         tender
# 84697  RE-SC-MDMQ-08-2021-41357-2022-04-28T11:30:12.1...         tender
# 84698  REOALC-GADMANTA01-21-2668-2022-04-30T12:21:31....         tender
# 84699  RE-GADMCN-17-21-LRG-67188-2022-05-04T11:48:52....         tender
# 84700  RE-HGADPCH-039-2021-2583-2022-05-04T11:39:57.9...         tender
#
#       language                       date  \
# 0           es  2022-05-07T07:11:05-05:00
# 1           es  2022-05-10T06:46:51-05:00
# 2           es  2022-05-11T06:48:06-05:00
# 3           es  2022-05-11T06:48:07-05:00
# 4           es  2022-05-14T07:33:35-05:00
# ...        ...                        ...
# 84696       es  2022-04-28T06:45:59-05:00
# 84697       es  2022-04-28T06:45:59-05:00
# 84698       es  2022-04-30T07:28:18-05:00
# 84699       es  2022-05-04T06:51:48-05:00
# 84700       es  2022-05-04T06:51:48-05:00
#
#                                                      tag  \
# 0      ["planning","tender","award","contract","imple...
# 1      ["planning","tender","award","contract","imple...
# 2      ["planning","tender","award","contract","imple...
# 3      ["planning","tender","award","contract","imple...
# 4               ["planning","tender","award","contract"]
# ...                                                  ...
# 84696  ["planning","tender","award","contract","imple...
# 84697  ["planning","tender","award","contract","imple...
# 84698           ["planning","tender","award","contract"]
# 84699           ["planning","tender","award","contract"]
# 84700  ["planning","tender","award","contract","imple...
#
#                              title  \
# 0        REGES-MPORTO-2021-13-2332
# 1           RE-EEASA-142-2021-3233
# 2        LICS-UNEMI-013-2021-43664
# 3      RE-EP-GMJ-DGF-1-2021-102953
# 4         LIC-EPFLP-01-2021-404551
# ...                            ...
# 84696   RE-EPMAPAS-001-2021-279324
# 84697     RE-SC-MDMQ-08-2021-41357
# 84698    REOALC-GADMANTA01-21-2668
# 84699    RE-GADMCN-17-21-LRG-67188
# 84700     RE-HGADPCH-039-2021-2583
#
#                                              description    status  ...  \
# 0      ESPACIOS DE DIFUSIÓN MASIVA A TRAVÉS DE VALLAS...  complete  ...
# 1      ?SERVICIO DE PAUTAJE EN EL MEDIO DE COMUNICACI...  complete  ...
# 2      CONTRATACION DE POLIZAS DE SEGUROMULTIRIESGO: ...  complete  ...
# 3      Elaboración y Adquisición de especiesvaloradas...  complete  ...
# 4      CONTRATACIÓN DE LA PÓLIZA DE SEGUROS MARÍTIMOS...  complete  ...
# ...                                                  ...       ...  ...
# 84696  CONTRATACION DE PAUTAS COMERCIALES EN EL PROGR...  complete  ...
# 84697  CONTRATACIÓN DEL SERVICIO COORDINACIÓN Y LOCUC...  complete  ...
# 84698  CONTRATACIÓN DEL SERVICIO DE ORGANIZACIÓN, PRO...  complete  ...
# 84699  PRESTACIÓN DE SERVICIOS DE INSPECCIÓN Y MANTEN...    active  ...
# 84700  CONTRATACIÓN DEL SERVICIO DE DIFUSIÓN, ELABORA...  complete  ...
#
#          amount                 dateSigned                     id_awards  \
# 0      13392.86  2021-05-31T00:00:00-05:00  4748528-REGES-MPORTO-2021-13
# 1       7000.00  2021-10-20T00:00:00-05:00     5104157-RE-EEASA-142-2021
# 2      59510.25  2021-06-23T00:00:00-05:00   4720310-LICS-UNEMI-013-2021
# 3       1700.00  2021-08-02T00:00:00-05:00  4930830-RE-EP-GMJ-DGF-1-2021
# 4     749885.00  2021-09-15T00:00:00-05:00     4980937-LIC-EPFLP-01-2021
# ...         ...                        ...                           ...
# 84696   2400.00  2021-08-23T00:00:00-05:00   4992062-RE-EPMAPAS-001-2021
# 84697  15600.00  2021-02-18T00:00:00-05:00    4661462-RE-SC-MDMQ-08-2021
# 84698 268000.00  2021-12-22T00:00:00-05:00  5151471-REOALC-GADMANTA01-21
# 84699  30590.89  2022-02-11T00:00:00-05:00   5302403-RE-GADMCN-17-21-LRG
# 84700 148474.03  2021-10-14T00:00:00-05:00   5099697-RE-HGADPCH-039-2021
#
#                      date_awards amount_awards currency  \
# 0      2021-05-07T14:21:51-05:00      13392.86      USD
# 1      2021-10-15T08:28:28-05:00       7000.00      USD
# 2      2021-04-23T10:25:08-05:00      59510.25      USD
# 3      2021-07-20T13:49:50-05:00       1700.00      USD
# 4      2021-08-30T08:43:16-05:00     749885.00      USD
# ...                          ...           ...      ...
# 84696  2021-08-18T10:04:49-05:00       2400.00      USD
# 84697  2021-02-10T11:27:11-05:00         15.60      USD
# 84698  2021-10-28T16:50:25-05:00     268000.00      USD
# 84699  2022-01-24T17:04:47-05:00      30590.89      USD
# 84700  2021-10-11T15:17:54-05:00     148474.03      USD
#
#                                                budget_id  budget_amount  \
# 0         2021.19.01.A100.150.530207.000.13.01.000.0.000       13392.86
# 1                                      52202030102120128        7000.00
# 2      2021.181.0000.0000.82.00.000.002.000.0910.5303...       70005.18
# 3                                              5.3.08.07        1700.00
# 4                                            5.1.2.02.01      910648.25
# ...                                                  ...            ...
# 84696                                          6.3.02.07        2400.00
# 84697                                             730222          15.60
# 84698                                             530205      268000.00
# 84699                                        730404.3613       30590.89
# 84700                                             730207      148474.03
#
#                  ruc   Provincia
# 0      1360000200001      Manabi
# 1      1890001439001  Tungurahua
# 2       968533430001      Guayas
# 3      1360000630001      Manabi
# 4      1768164300001   Pichincha
# ...              ...         ...
# 84696   968586470001      Guayas
# 84697  1760003410001   Pichincha
# 84698  1360000980001      Manabi
# 84699   968532700001      Guayas
# 84700   660000280001  Chimborazo
#
# [84701 rows x 33 columns]

# %%
df_contract = pd.read_csv("../data/contracts_2021.csv")

# %%
df_award = pd.read_csv("../data/awards_2021.csv")
# Out:
# /home/itscitlalli/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3397: DtypeWarning: Columns (4,6,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_tender = pd.read_csv("../data/tender_2021.csv")
# Out:
# /home/itscitlalli/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3397: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
filt_tender = df_tender[["ocid", "procuringEntity_name", "procuringEntity_id", "procurementMethod"]]
filt_award = df_award[["ocid", "id", "amount",]]
filt_contract = df_contract[["ocid", "id", "amount", "contractPeriod_durationInDays"]]

# %%
df_tender.dtypes
# Out:
# ocid                             object
# release_id                       object
# id                               object
# title                            object
# description                      object
# status                           object
# procuringEntity_id               object
# procuringEntity_name             object
# value_amount                    float64
# value_currency                   object
# procurementMethod                object
# procurementMethodDetails         object
# mainProcurementCategory          object
# awardCriteria                    object
# tenderPeriod_startDate           object
# tenderPeriod_endDate             object
# tenderPeriod_maxExtentDate       object
# tenderPeriod_durationInDays     float64
# enquiryPeriod_startDate          object
# enquiryPeriod_endDate            object
# enquiryPeriod_maxExtentDate      object
# enquiryPeriod_durationInDays    float64
# hasEnquiries                     object
# eligibilityCriteria              object
# awardPeriod_startDate            object
# awardPeriod_endDate              object
# awardPeriod_maxExtentDate        object
# awardPeriod_durationInDays      float64
# numberOfTenderers               float64
# dtype: object

# %%
df_contract.dtypes
# Out:
# ocid                              object
# release_id                        object
# id                                object
# awardID                           object
# title                            float64
# description                      float64
# status                            object
# contractPeriod_startDate          object
# contractPeriod_endDate            object
# contractPeriod_maxExtentDate     float64
# contractPeriod_durationInDays    float64
# amount                           float64
# currency                          object
# dateSigned                        object
# dtype: object

# %%
preg1 = filt_award.merge(filt_contract, left_on="ocid", right_on="ocid", how="left", suffixes=("_aw", "_ctr"))
preg1 = preg1[~(preg1["amount_ctr"].isnull()) & ~(preg1["amount_aw"].isnull())]
preg1 = preg1.merge(filt_tender, left_on="ocid", right_on="ocid", how="left")
preg1
# Out:
#                                            ocid                         id_aw  \
# 0          ocds-5wno2w-MCBS-DNA-003-2021-178618     4726509-MCBS-DNA-003-2021
# 1           ocds-5wno2w-LCC-GADMQ-001-2021-2453    5031904-LCC-GADMQ-001-2021
# 2           ocds-5wno2w-SIE-DNA-003-2021-178618      1763312-SIE-DNA-003-2021
# 3           ocds-5wno2w-SIE-GADMCA-20-2021-3680    1804134-SIE-GADMCA-20-2021
# 4       ocds-5wno2w-SIE-UNIAD-2021-003-R-270725  1749595-SIE-UNIAD-2021-003-R
# ...                                         ...                           ...
# 171239    ocds-5wno2w-REOALC-GADMANTA01-21-2668  5151471-REOALC-GADMANTA01-21
# 171240     ocds-5wno2w-MCBS-DNA-005-2021-178618     4862272-MCBS-DNA-005-2021
# 171241    ocds-5wno2w-MCS-CCFFAA-002-ABR21-2539  4744578-MCS-CCFFAA-002-ABR21
# 171242    ocds-5wno2w-RE-GADMCN-17-21-LRG-67188   5302403-RE-GADMCN-17-21-LRG
# 171243     ocds-5wno2w-RE-HGADPCH-039-2021-2583   5099697-RE-HGADPCH-039-2021
#
#         amount_aw                        id_ctr  amount_ctr  \
# 0        24706.08     2115897-MCBS-DNA-003-2021    24706.08
# 1       258933.74    2092647-LCC-GADMQ-001-2021   258933.74
# 2        11209.11      2115931-SIE-DNA-003-2021    11209.11
# 3       173720.00    2086901-SIE-GADMCA-20-2021   173720.00
# 4        25882.36  2071544-SIE-UNIAD-2021-003-R    25882.36
# ...           ...                           ...         ...
# 171239  268000.00  2115646-REOALC-GADMANTA01-21   268000.00
# 171240   28823.77     2115899-MCBS-DNA-005-2021    28823.77
# 171241    7589.29  2072552-MCS-CCFFAA-002-ABR21     7589.29
# 171242   30590.89   2115789-RE-GADMCN-17-21-LRG    30590.89
# 171243  148474.03   2108207-RE-HGADPCH-039-2021   148474.03
#
#         contractPeriod_durationInDays  \
# 0                              365.00
# 1                              365.00
# 2                              365.00
# 3                               60.00
# 4                              240.00
# ...                               ...
# 171239                          60.00
# 171240                         365.00
# 171241                         239.00
# 171242                         365.00
# 171243                         180.00
#
#                                      procuringEntity_name  \
# 0                    DIRECCION NACIONAL DE ANTINARCOTICOS
# 1       GOBIERNO AUTONOMO DESCENTRALIZADO MUNICIPAL DE...
# 2                    DIRECCION NACIONAL DE ANTINARCOTICOS
# 3       GOBIERNO AUTONOMO DESCENTRALIZADO MUNICIPAL DE...
# 4       MINISTERIO DE GOBIERNO UNIDAD NACIONAL DE INVE...
# ...                                                   ...
# 171239  GOBIERNO AUTONOMO DESCENTRALIZADO MUNICIPAL DE...
# 171240               DIRECCION NACIONAL DE ANTINARCOTICOS
# 171241                                   COMANDO CONJUNTO
# 171242  GOBIERNO AUTONOMO DESCENTRALIZADO MUNICIPAL DE...
# 171243  HONORABLE GOBIERNO AUTONOMO DESCENTRALIZADO DE...
#
#                  procuringEntity_id procurementMethod
# 0       EC-RUC-1768040760001-178618         selective
# 1         EC-RUC-1260000650001-2453           limited
# 2       EC-RUC-1768040760001-178618              open
# 3         EC-RUC-0660000440001-3680              open
# 4       EC-RUC-1768155820001-270725              open
# ...                             ...               ...
# 171239    EC-RUC-1360000980001-2668            direct
# 171240  EC-RUC-1768040760001-178618         selective
# 171241    EC-RUC-1768012630001-2539         selective
# 171242   EC-RUC-0968532700001-67188            direct
# 171243    EC-RUC-0660000280001-2583            direct
#
# [171244 rows x 9 columns]

# %%
provincias = pd.read_csv("../data/provinciasRUC.csv")

# %%
preg1['ruc']=preg1['procuringEntity_id'].str.split('-').str[2]

# %%
preg1['codigoProvincia']=preg1['ruc'].str[:2].astype(int)
preg1 = preg1.merge(provincias,left_on = "codigoProvincia", right_on="Codigo", how="left")

# %%
preg1.drop(columns=["codigoProvincia","Codigo"], inplace=True)

# %%
preg1["diferencia_absoluta"] = np.abs(preg1["amount_aw"] - preg1["amount_ctr"])
preg1.head()
# Out:
#                                       ocid                         id_aw  \
# 0     ocds-5wno2w-MCBS-DNA-003-2021-178618     4726509-MCBS-DNA-003-2021
# 1      ocds-5wno2w-LCC-GADMQ-001-2021-2453    5031904-LCC-GADMQ-001-2021
# 2      ocds-5wno2w-SIE-DNA-003-2021-178618      1763312-SIE-DNA-003-2021
# 3      ocds-5wno2w-SIE-GADMCA-20-2021-3680    1804134-SIE-GADMCA-20-2021
# 4  ocds-5wno2w-SIE-UNIAD-2021-003-R-270725  1749595-SIE-UNIAD-2021-003-R
#
#    amount_aw                        id_ctr  amount_ctr  \
# 0   24706.08     2115897-MCBS-DNA-003-2021    24706.08
# 1  258933.74    2092647-LCC-GADMQ-001-2021   258933.74
# 2   11209.11      2115931-SIE-DNA-003-2021    11209.11
# 3  173720.00    2086901-SIE-GADMCA-20-2021   173720.00
# 4   25882.36  2071544-SIE-UNIAD-2021-003-R    25882.36
#
#    contractPeriod_durationInDays  \
# 0                         365.00
# 1                         365.00
# 2                         365.00
# 3                          60.00
# 4                         240.00
#
#                                 procuringEntity_name  \
# 0               DIRECCION NACIONAL DE ANTINARCOTICOS
# 1  GOBIERNO AUTONOMO DESCENTRALIZADO MUNICIPAL DE...
# 2               DIRECCION NACIONAL DE ANTINARCOTICOS
# 3  GOBIERNO AUTONOMO DESCENTRALIZADO MUNICIPAL DE...
# 4  MINISTERIO DE GOBIERNO UNIDAD NACIONAL DE INVE...
#
#             procuringEntity_id procurementMethod            ruc   Provincia  \
# 0  EC-RUC-1768040760001-178618         selective  1768040760001   Pichincha
# 1    EC-RUC-1260000650001-2453           limited  1260000650001    Los Rios
# 2  EC-RUC-1768040760001-178618              open  1768040760001   Pichincha
# 3    EC-RUC-0660000440001-3680              open  0660000440001  Chimborazo
# 4  EC-RUC-1768155820001-270725              open  1768155820001   Pichincha
#
#    diferencia_absoluta
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00

# %% [markdown]
# ¿Cuáles fueron los métodos de adquisición que generaron la mayor diferencia de contrato a nivel nacional y por provincias?

# %%
metodo_licitacion_prov = preg1.groupby(["Provincia", "procurementMethod"])["diferencia_absoluta"].agg('sum').reset_index()
#metodo_licitacion_nac = df.groupby("procurementMethodDetails").agg({'diferencia_amount': ['sum', 'mean', 'min', 'max','size']}).reset_index()
metodo_licitacion_nac = preg1.groupby("procurementMethod")["diferencia_absoluta"].agg('sum').reset_index()

# %%
maximo_difmont = metodo_licitacion_nac.diferencia_absoluta.max()
maximo_difmont
# Out:
# 6423067982687.59

# %%
min_difmont = metodo_licitacion_nac.diferencia_absoluta.min()
min_difmont
# Out:
# 17003555.97

# %%
table_prov= pd.pivot_table(metodo_licitacion_prov, index='Provincia', columns=['procurementMethod'], aggfunc= ["sum"],values="diferencia_absoluta")

# %%
fig, ax = plt.subplots(figsize=(11.7, 8.27))
ax = sns.barplot(y='diferencia_absoluta', x='procurementMethod',data=metodo_licitacion_nac)
ax.title.set_text('Métodos de adquisición que generaron la mayor diferencia absoluta entre precio adjudicado y precio declarado de contrato a nivel nacional\n')
ax.set_ylabel('Diferencia de cantidad del contrato')
ax.set_xlabel('Métodos de adquisición')
ax.ticklabel_format(useOffset=False, style='plain', axis= 'y')
plt.savefig("preg9_nac.png", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(11.7, 8.27))
ax = sns.heatmap(table_prov,cmap='YlGnBu')
ax.title.set_text('Métodos de adquisición que generaron la mayor diferencia absoluta entre precio adjudicado y precio declarado de contrato por provincia\n')
ax.set_xlabel('Métodos de adquisición')
ax.set_ylabel('Provincia')
plt.show()
plt.savefig("preg9_prov.png", bbox_inches='tight')

# %%
#sns.barplot(x='name',y='totalCount',data=metodo_licitacion_nac)
fig,axs = plt.subplots(nrows=2,ncols=1,figsize=(15,30))
ax = sns.barplot(y='diferencia_absoluta', x='procurementMethod', ax=axs[0],data=metodo_licitacion_nac)
ax.title.set_text('Métodos de adquisición que generaron la mayor diferencia absoluta entre precio adjudicado y precio declarado de contrato a nivel nacional\n')
ax.set_ylabel('Diferencia de cantidad del contrato')
ax.set_xlabel('Métodos de adquisición')
ax.ticklabel_format(useOffset=False, style='plain', axis= 'y')
#ax.set_xlim(min_difmont, 0)
ax = sns.heatmap(table_prov,ax=axs[1],cmap='YlGnBu')
ax.title.set_text('Métodos de adquisición que generaron la mayor diferencia absoluta entre precio adjudicado y precio declarado de contrato por provincia\n')
ax.set_xlabel('Métodos de adquisición')
ax.set_ylabel('Provincia')
plt.show()

# %% [markdown]
# ¿Cuál es la frecuencia más alta o representativa del monto del contrato teniendo en cuenta la duración en días de este?

# %%
df_frec = preg1[["contractPeriod_durationInDays","amount_ctr"]]
df_frec
# Out:
# 1.0

# %%
df_frec["amount_ctr"].unique()
# Out:
# array([ 24706.08, 258933.74,  11209.11, ...,   7589.29,  30590.89,
#        148474.03])

# %%
df_frec["range_monto"] = pd.cut(df_frec["amount_ctr"], bins=10)
df_frec["range_dias"] = pd.cut(df_frec["contractPeriod_durationInDays"], bins=5)
# Out:
# /tmp/ipykernel_15195/3707545326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frec["range_monto"] = pd.cut(df_frec["amount_ctr"], bins=10)
# /tmp/ipykernel_15195/3707545326.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frec["range_dias"] = pd.cut(df_frec["contractPeriod_durationInDays"], bins=5)

# %%
df_frec["range_monto"].unique()
# Out:
# [(-3199999999.99, 320000000000.009], (2880000000000.001, 3200000000000.0]]
# Categories (10, interval[float64, right]): [(-3199999999.99, 320000000000.009] < (320000000000.009, 640000000000.008] < (640000000000.008, 960000000000.007] < (960000000000.007, 1280000000000.006] ... (1920000000000.004, 2240000000000.003] < (2240000000000.003, 2560000000000.002] < (2560000000000.002, 2880000000000.001] < (2880000000000.001, 3200000000000.0]]

# %%
table= pd.pivot_table(df_frec, index=['range_dias'], columns='range_monto', aggfunc=np.size,values="amount_ctr")

# %%
table
# Out:
# range_monto       (-3199999999.99, 320000000000.009]  \
# range_dias
# (-2.769, 754.8]                            170914.00
# (754.8, 1508.6]                               244.00
# (1508.6, 2262.4]                               52.00
# (2262.4, 3016.2]                                7.00
# (3016.2, 3770.0]                               21.00
#
# range_monto       (2880000000000.001, 3200000000000.0]
# range_dias
# (-2.769, 754.8]                                   2.00
# (754.8, 1508.6]                                    NaN
# (1508.6, 2262.4]                                   NaN
# (2262.4, 3016.2]                                   NaN
# (3016.2, 3770.0]                                   NaN

# %%
plt.figure(figsize = (10,7))
plt.title('Frecuencia del monto según la duración del contrato en días \n')
sns.heatmap(table,cmap='YlGnBu')
plt.xlabel('Monto')
plt.ylabel('Duración de contrato en días')
plt.savefig("preg10.png", bbox_inches='tight')
