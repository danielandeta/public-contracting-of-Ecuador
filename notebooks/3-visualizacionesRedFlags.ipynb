# %%
import pandas as pd

# %%
df = pd.read_csv("../data/datasetRedFlags.csv")
df
# Out:
#        Unnamed: 0                                    ocid  \
# 0               0   ocds-5wno2w-LICS-UNEMI-013-2021-43664
# 1               1    ocds-5wno2w-LIC-EPFLP-01-2021-404551
# 2               2   ocds-5wno2w-LICS-DD07D03-01-2021-9272
# 3               3  ocds-5wno2w-R2COTBSGSXXI-17-2020-71669
# 4               4   ocds-5wno2w-LICS-CBSE-001-2021-222424
# ...           ...                                     ...
# 77944       77944  ocds-5wno2w-LICS-GADMSCP-01-2021-59276
# 77945       77945   ocds-5wno2w-LICS-CARCHI-001-2021-2481
# 77946       77946  ocds-5wno2w-COTBS-DINAF-01-2021-183518
# 77947       77947  ocds-5wno2w-COTS-GADMCD-2021-003-94742
# 77948       77948   ocds-5wno2w-COTBS-CSI-003-2021-179005
#
#                                                       id initiationType  \
# 0      LICS-UNEMI-013-2021-43664-2022-05-11T11:32:30....         tender
# 1      LIC-EPFLP-01-2021-404551-2022-05-14T12:25:47.8...         tender
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# ocid                              object
# id                                object
# initiationType                    object
# language                          object
# date                              object
# tag                               object
# title                             object
# description                       object
# status                            object
# procuringEntity_id                object
# procuringEntity_name              object
# value_amount                     float64
# value_currency                    object
# procurementMethod                 object
# procurementMethodDetails          object
# numberOfTenderers                float64
# enquiryPeriod_durationInDays     float64
# tenderPeriod_durationInDays      float64
# id_supplier                       object
# name                              object
# id_contracts                      object
# status_contracts                  object
# ...

# %%
licitacion = df.groupby(['procuringEntity_name']).agg({'tenderPeriod_durationInDays': ['mean', 'min', 'max','size']}).reset_index()
licitacion
# Out:
#                                   procuringEntity_name  \
#
# 0    ACERIAS NACIONALES DEL ECUADOR SOCIEDAD ANONIM...
# 1    AGENCIA DE REGULACION Y CONTROL DE LAS TELECOM...
# 2    AGENCIA NACIONAL DE REGULACION, CONTROL Y VIGI...
# 3    AGENCIA NACIONAL DE REGULACIÓN Y CONTROL DEL T...
# 4                                    ASAMBLEA NACIONAL
# ..                                                 ...
# 571                 Universidad Nacional de Chimborazo
# 572                     Universidad Tecnica de Machala
# 573                      Universidad Técnica de Manabí
# 574                   VICEPRESIDENCIA DE LA REPUBLICA
# 575  comando provincial de la policia del guayas nr...
#
#     tenderPeriod_durationInDays
#                            mean   min   max size
# 0                          15.4  10.0  28.0    5
# 1                          14.0  14.0  14.0    1
# 2                          15.0  15.0  15.0    1
# 3                           9.0   9.0   9.0    1
# ...
